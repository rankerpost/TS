# %% [markdown]
# # Bivariate Time Series Manipulation & Visualization

# %% [markdown]
# ## Overview

# %% [markdown]
# <style>
#     table.custom-table {
#         max-width: 1000px;
#         width: 100%;
#         margin: 0 auto; /* centers the table on the page */
#     }
#
#     table.custom-table td {
#         background-color: #fff;
#     }
#
#     table.custom-table th, table.custom-table td {
#         text-align: center;
#         vertical-align: middle;
#         padding: 5px;
#         width: 333px; /* distribute the total width equally among three columns */
#     }
#
#     table.custom-table img {
#         width: 100%;
#         display: block; /* removes any gap under the image */
#     }
# </style>
#
#
# <table class="custom-table">
#     <thead>
#         <tr>
#             <th>Output: Accumulated Generation</th>
#             <th>Output: Technology Relationship</th>
#             <th>Input: Hourly Energy Generation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <img src="src/02_output_2.png" alt="Solar Image 1">
#             </td>
#             <td>
#                 <img src="src/02_output_1.png" alt="Solar Image 2">
#             </td>
#             <td>
#                 <img src="src/02_input.png" alt="Solar Image 3">
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Data

# %%
import pandas as pd

df = pd.read_csv('../../../data/energy_generation_hourly_year.csv', index_col=0, parse_dates=True)
df
# Out:
#                       Coal  Cogeneration  Combined Cycle (Gas)     Eolic  \
# time
# 2022-09-01 00:00:00  695.0        1155.1             14748.950  4387.050
# 2022-09-01 01:00:00  750.0        1162.1             14255.600  4008.900
# ...                    ...           ...                   ...       ...
# 2023-08-31 22:00:00  477.5        2153.4             10575.375  3057.950
# 2023-08-31 23:00:00  500.0        2127.7              9988.875  3028.675
#
#                      Hydraulic  Non-Renewable Residues  Nuclear  \
# time
# 2022-09-01 00:00:00    899.675                   273.7   6869.9
# 2022-09-01 01:00:00    850.200                   271.6   6881.9
# ...                        ...                     ...      ...
# 2023-08-31 22:00:00   3541.400                   239.4   6866.0
# 2023-08-31 23:00:00   3159.500                   240.8   6869.0
#
#                      Pumped Storage Hydropower  Renewables Other  \
# time
# 2022-09-01 00:00:00                     201.60             516.6
# 2022-09-01 01:00:00                     117.70             514.4
# ...                                        ...               ...
# 2023-08-31 22:00:00                     946.25             510.7
# 2023-08-31 23:00:00                     334.95             511.9
#
#                      Solar Photovoltaic  Solar Thermal
# time
# 2022-09-01 00:00:00                 1.0          287.7
# 2022-09-01 01:00:00                 1.0          247.7
# ...                                 ...            ...
# 2023-08-31 22:00:00                17.6          607.9
# 2023-08-31 23:00:00                17.4          619.8
#
# [8759 rows x 11 columns]

# %%
# Out:
#                      Solar Photovoltaic     Eolic
# time
# 2022-09-01 00:00:00                 1.0  4387.050
# 2022-09-01 01:00:00                 1.0  4008.900
# ...                                 ...       ...
# 2023-08-31 22:00:00                17.6  3057.950
# 2023-08-31 23:00:00                17.4  3028.675
#
# [8759 rows x 2 columns]

# %% [markdown]
# ## Resampling the Time
# - [Date offset `rule` list](https://pandas.pydata.org/docs/user_guide/timeseries.html#dateoffset-objects)
# - [Pandas plot `kind` list](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Daily

# %%
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ### Monthly

# %%
# Out:
# <Axes: xlabel='time'>

# %%
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ## Visualize Time Series Correlation

# %%
# Out:
#             Solar Photovoltaic        Eolic
# time
# 2022-09-01          695863.476   864037.706
# 2022-09-08          555033.259   871012.693
# ...                        ...          ...
# 2023-08-24          900329.814  1164917.767
# 2023-08-31          138880.021    69646.772
#
# [53 rows x 2 columns]

# %% [markdown]
# ## Data Visualization with Plotly
#
# - [Plotly Express Overview](https://plotly.com/python/plotly-express/#overview)

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### Transform object to DataFrame
#
# > Only if you don't have a DataFrame yet.

# %%
# Out:
#                      Solar Photovoltaic     Eolic
# time
# 2022-09-01 00:00:00                 1.0  4387.050
# 2022-09-01 01:00:00                 1.0  4008.900
# ...                                 ...       ...
# 2023-08-31 22:00:00                17.6  3057.950
# 2023-08-31 23:00:00                17.4  3028.675
#
# [8759 rows x 2 columns]

# %% [markdown]
# ### Time series categories in one column

# %%
# Out:
#                              technology  generation
# time
# 2022-09-01 00:00:00  Solar Photovoltaic       1.000
# 2022-09-01 01:00:00  Solar Photovoltaic       1.000
# ...                                 ...         ...
# 2023-08-31 22:00:00               Eolic    3057.950
# 2023-08-31 23:00:00               Eolic    3028.675
#
# [17518 rows x 2 columns]

# %% [markdown]
# ### Create columns with datetime information

# %%
# Out:
#                              technology  generation  year  month  day  hour
# time
# 2022-09-01 00:00:00  Solar Photovoltaic       1.000  2022      9    1     0
# 2022-09-01 01:00:00  Solar Photovoltaic       1.000  2022      9    1     1
# ...                                 ...         ...   ...    ...  ...   ...
# 2023-08-31 22:00:00               Eolic    3057.950  2023      8   31    22
# 2023-08-31 23:00:00               Eolic    3028.675  2023      8   31    23
#
# [17518 rows x 6 columns]

# %% [markdown]
# ### Process `pivot_table`
#
# - Use this methodology.

# %%
# Out:
# year                       2022                                         \
# month                        9            10           11           12
# technology
# Eolic               4058314.734  5002114.206  6657801.544  5671385.864
# Solar Photovoltaic  2636219.180  2056758.270  1535995.490  1176871.031
#
# year                       2023                                         \
# month                        1            2            3            4
# technology
# Eolic               7426712.678  4700334.703  6603070.491  4844750.027
# Solar Photovoltaic  1744956.450  2181165.122  2985426.080  3635891.249
#
# year
# month                        5            6            7            8
# technology
# Eolic               5370790.331  3083011.561  3759950.872  4197239.743
# Solar Photovoltaic  3803151.814  3855930.011  4491017.672  4403223.582

# %% [markdown]
# ### Style DataFrame

# %%
# Out:
# <style type="text/css">
# #T_13273_row0_col0 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_13273_row0_col1 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_13273_row0_col2 {
#   background-color: #a53603;
#   color: #f1f1f1;
# }
# #T_13273_row0_col3 {
#   background-color: #de5005;
#   color: #f1f1f1;
# }
# #T_13273_row0_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_13273_row0_col5 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_13273_row0_col6 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_13273_row0_col7 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_13273_row0_col8 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_13273_row0_col9 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_13273_row0_col10 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_13273_row0_col11 {
#   background-color: #fd9243;
#   color: #000000;
# }
# #T_13273_row1_col0 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_13273_row1_col1 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_13273_row1_col2 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_13273_row1_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_13273_row1_col4 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_13273_row1_col5 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_13273_row1_col6 {
#   background-color: #fdc590;
#   color: #000000;
# }
# #T_13273_row1_col7 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_13273_row1_col8 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_13273_row1_col9 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_13273_row1_col10 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_13273_row1_col11 {
#   background-color: #fb8836;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13273">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_13273_level0_col0" class="col_heading level0 col0" colspan="4">2022</th>
#       <th id="T_13273_level0_col4" class="col_heading level0 col4" colspan="8">2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >month</th>
#       <th id="T_13273_level1_col0" class="col_heading level1 col0" >9</th>
#       <th id="T_13273_level1_col1" class="col_heading level1 col1" >10</th>
#       <th id="T_13273_level1_col2" class="col_heading level1 col2" >11</th>
#       <th id="T_13273_level1_col3" class="col_heading level1 col3" >12</th>
#       <th id="T_13273_level1_col4" class="col_heading level1 col4" >1</th>
#       <th id="T_13273_level1_col5" class="col_heading level1 col5" >2</th>
#       <th id="T_13273_level1_col6" class="col_heading level1 col6" >3</th>
#       <th id="T_13273_level1_col7" class="col_heading level1 col7" >4</th>
#       <th id="T_13273_level1_col8" class="col_heading level1 col8" >5</th>
#       <th id="T_13273_level1_col9" class="col_heading level1 col9" >6</th>
#       <th id="T_13273_level1_col10" class="col_heading level1 col10" >7</th>
#       <th id="T_13273_level1_col11" class="col_heading level1 col11" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >technology</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13273_level0_row0" class="row_heading level0 row0" >Eolic</th>
#       <td id="T_13273_row0_col0" class="data row0 col0" >4058.31</td>
#       <td id="T_13273_row0_col1" class="data row0 col1" >5002.11</td>
#       <td id="T_13273_row0_col2" class="data row0 col2" >6657.80</td>
#       <td id="T_13273_row0_col3" class="data row0 col3" >5671.39</td>
#       <td id="T_13273_row0_col4" class="data row0 col4" >7426.71</td>
#       <td id="T_13273_row0_col5" class="data row0 col5" >4700.33</td>
#       <td id="T_13273_row0_col6" class="data row0 col6" >6603.07</td>
#       <td id="T_13273_row0_col7" class="data row0 col7" >4844.75</td>
#       <td id="T_13273_row0_col8" class="data row0 col8" >5370.79</td>
#       <td id="T_13273_row0_col9" class="data row0 col9" >3083.01</td>
#       <td id="T_13273_row0_col10" class="data row0 col10" >3759.95</td>
#       <td id="T_13273_row0_col11" class="data row0 col11" >4197.24</td>
#     </tr>
#     <tr>
#       <th id="T_13273_level0_row1" class="row_heading level0 row1" >Solar Photovoltaic</th>
#       <td id="T_13273_row1_col0" class="data row1 col0" >2636.22</td>
#       <td id="T_13273_row1_col1" class="data row1 col1" >2056.76</td>
#       <td id="T_13273_row1_col2" class="data row1 col2" >1536.00</td>
#       <td id="T_13273_row1_col3" class="data row1 col3" >1176.87</td>
#       <td id="T_13273_row1_col4" class="data row1 col4" >1744.96</td>
#       <td id="T_13273_row1_col5" class="data row1 col5" >2181.17</td>
#       <td id="T_13273_row1_col6" class="data row1 col6" >2985.43</td>
#       <td id="T_13273_row1_col7" class="data row1 col7" >3635.89</td>
#       <td id="T_13273_row1_col8" class="data row1 col8" >3803.15</td>
#       <td id="T_13273_row1_col9" class="data row1 col9" >3855.93</td>
#       <td id="T_13273_row1_col10" class="data row1 col10" >4491.02</td>
#       <td id="T_13273_row1_col11" class="data row1 col11" >4403.22</td>
#     </tr>
#   </tbody>
# </table>
