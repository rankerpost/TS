# %% [markdown]
# # Multivariate Time Series Manipulation & Visualization

# %% [markdown]
# ## Overview

# %% [markdown]
# <style>
#     table.custom-table {
#         max-width: 1000px;
#         width: 100%;
#         margin: 0 auto; /* centers the table on the page */
#     }
#
#     table.custom-table td {
#         background-color: #fff;
#     }
#
#     table.custom-table th, table.custom-table td {
#         text-align: center;
#         vertical-align: middle;
#         padding: 5px;
#         width: 333px; /* distribute the total width equally among three columns */
#     }
#
#     table.custom-table img {
#         width: 100%;
#         display: block; /* removes any gap under the image */
#     }
# </style>
#
#
# <table class="custom-table">
#     <thead>
#         <tr>
#             <th>Output: Accumulated Generation</th>
#             <th>Output: Technology Relationship</th>
#             <th>Input: Hourly Energy Generation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <img src="src/03_output_2.png" alt="Solar Image 1">
#             </td>
#             <td>
#                 <img src="src/03_output_1.png" alt="Solar Image 2">
#             </td>
#             <td>
#                 <img src="src/03_input.png" alt="Solar Image 3">
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Data

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
df = pd.read_csv('../../../data/energy_generation_hourly_year.csv', index_col=0, parse_dates=True)
df
# Out:
#                       Coal  Cogeneration  Combined Cycle (Gas)     Eolic  \
# time
# 2022-09-01 00:00:00  695.0        1155.1             14748.950  4387.050
# 2022-09-01 01:00:00  750.0        1162.1             14255.600  4008.900
# ...                    ...           ...                   ...       ...
# 2023-08-31 22:00:00  477.5        2153.4             10575.375  3057.950
# 2023-08-31 23:00:00  500.0        2127.7              9988.875  3028.675
#
#                      Hydraulic  Non-Renewable Residues  Nuclear  \
# time
# 2022-09-01 00:00:00    899.675                   273.7   6869.9
# 2022-09-01 01:00:00    850.200                   271.6   6881.9
# ...                        ...                     ...      ...
# 2023-08-31 22:00:00   3541.400                   239.4   6866.0
# 2023-08-31 23:00:00   3159.500                   240.8   6869.0
#
#                      Pumped Storage Hydropower  Renewables Other  \
# time
# 2022-09-01 00:00:00                     201.60             516.6
# 2022-09-01 01:00:00                     117.70             514.4
# ...                                        ...               ...
# 2023-08-31 22:00:00                     946.25             510.7
# 2023-08-31 23:00:00                     334.95             511.9
#
#                      Solar Photovoltaic  Solar Thermal
# time
# 2022-09-01 00:00:00                 1.0          287.7
# 2022-09-01 01:00:00                 1.0          247.7
# ...                                 ...            ...
# 2023-08-31 22:00:00                17.6          607.9
# 2023-08-31 23:00:00                17.4          619.8
#
# [8759 rows x 11 columns]

# %% [markdown]
# ## Resampling the Time
# - [Date offset `rule` list](https://pandas.pydata.org/docs/user_guide/timeseries.html#dateoffset-objects)
# - [Pandas plot `kind` list](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Daily

# %%
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ### Monthly

# %%
# Out:
# <Axes: xlabel='time'>

# %%
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ## Visualize Time Series Correlation

# %%
# Out:
#                   Coal  Cogeneration  Combined Cycle (Gas)        Eolic  \
# time
# 2022-09-01  136546.000    172293.173           1923790.391   864037.706
# 2022-09-08  162789.817    155962.252           1936149.859   871012.693
# ...                ...           ...                   ...          ...
# 2023-08-24  100683.501    302946.699           1029472.369  1164917.767
# 2023-08-31   12551.600     49434.506            157466.900    69646.772
#
#              Hydraulic  Non-Renewable Residues      Nuclear  \
# time
# 2022-09-01  172805.520               44596.742  1157554.000
# 2022-09-08  259821.964               43652.217  1161943.117
# ...                ...                     ...          ...
# 2023-08-24  216970.617               39295.900  1127421.700
# 2023-08-31   40281.783                5047.100   164489.725
#
#             Pumped Storage Hydropower  Renewables Other  Solar Photovoltaic  \
# time
# 2022-09-01                  63015.933         82948.067          695863.476
# 2022-09-08                  60223.724         79612.056          555033.259
# ...                               ...               ...                 ...
# 2023-08-24                  75029.051         75374.591          900329.814
# 2023-08-31                  12067.300         11374.631          138880.021
#
#             Solar Thermal
# time
# 2022-09-01     133947.275
# 2022-09-08      82339.811
# ...                   ...
# 2023-08-24     152151.446
# 2023-08-31      22387.216
#
# [53 rows x 11 columns]

# %% [markdown]
# ## Correlation Matrix
#
# - [Plotly Express Overview](https://plotly.com/python/plotly-express/#overview)

# %% [markdown]
# ### Scatter Matrix

# %% [markdown]
# ### Correlation Heatmap

# %%
# Out:
#                         Coal  Cogeneration  Combined Cycle (Gas)     Eolic  \
# Coal                1.000000     -0.188149              0.518225 -0.084500
# Cogeneration       -0.188149      1.000000             -0.182540  0.070660
# ...                      ...           ...                   ...       ...
# Solar Photovoltaic -0.296412      0.422146              0.002034 -0.335556
# Solar Thermal      -0.249978      0.244770             -0.001624 -0.344434
#
#                     Hydraulic  Non-Renewable Residues   Nuclear  \
# Coal                 0.172777                0.463225  0.444694
# Cogeneration         0.172892                0.070449  0.181007
# ...                       ...                     ...       ...
# Solar Photovoltaic  -0.340156               -0.060634  0.151145
# Solar Thermal       -0.397340               -0.088349  0.150533
#
#                     Pumped Storage Hydropower  Renewables Other  \
# Coal                                -0.141163          0.445223
# Cogeneration                         0.031765          0.382826
# ...                                       ...               ...
# Solar Photovoltaic                   0.092960          0.049405
# Solar Thermal                        0.110195         -0.071333
#
#                     Solar Photovoltaic  Solar Thermal
# Coal                         -0.296412      -0.249978
# Cogeneration                  0.422146       0.244770
# ...                                ...            ...
# Solar Photovoltaic            1.000000       0.955715
# Solar Thermal                 0.955715       1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# ## Other Plots

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### Transform object to DataFrame
#
# > Only if you don't have a DataFrame yet.

# %%
# Out:
#                       Coal  Cogeneration  Combined Cycle (Gas)     Eolic  \
# time
# 2022-09-01 00:00:00  695.0        1155.1             14748.950  4387.050
# 2022-09-01 01:00:00  750.0        1162.1             14255.600  4008.900
# ...                    ...           ...                   ...       ...
# 2023-08-31 22:00:00  477.5        2153.4             10575.375  3057.950
# 2023-08-31 23:00:00  500.0        2127.7              9988.875  3028.675
#
#                      Hydraulic  Non-Renewable Residues  Nuclear  \
# time
# 2022-09-01 00:00:00    899.675                   273.7   6869.9
# 2022-09-01 01:00:00    850.200                   271.6   6881.9
# ...                        ...                     ...      ...
# 2023-08-31 22:00:00   3541.400                   239.4   6866.0
# 2023-08-31 23:00:00   3159.500                   240.8   6869.0
#
#                      Pumped Storage Hydropower  Renewables Other  \
# time
# 2022-09-01 00:00:00                     201.60             516.6
# 2022-09-01 01:00:00                     117.70             514.4
# ...                                        ...               ...
# 2023-08-31 22:00:00                     946.25             510.7
# 2023-08-31 23:00:00                     334.95             511.9
#
#                      Solar Photovoltaic  Solar Thermal
# time
# 2022-09-01 00:00:00                 1.0          287.7
# 2022-09-01 01:00:00                 1.0          247.7
# ...                                 ...            ...
# 2023-08-31 22:00:00                17.6          607.9
# 2023-08-31 23:00:00                17.4          619.8
#
# [8759 rows x 11 columns]

# %% [markdown]
# ### Time series categories in one column

# %%
# Out:
#                         technology  generation
# time
# 2022-09-01 00:00:00           Coal       695.0
# 2022-09-01 01:00:00           Coal       750.0
# ...                            ...         ...
# 2023-08-31 22:00:00  Solar Thermal       607.9
# 2023-08-31 23:00:00  Solar Thermal       619.8
#
# [96349 rows x 2 columns]

# %% [markdown]
# ### Create columns with datetime information

# %%
# Out:
#                         technology  generation  year  month  day  hour
# time
# 2022-09-01 00:00:00           Coal       695.0  2022      9    1     0
# 2022-09-01 01:00:00           Coal       750.0  2022      9    1     1
# ...                            ...         ...   ...    ...  ...   ...
# 2023-08-31 22:00:00  Solar Thermal       607.9  2023      8   31    22
# 2023-08-31 23:00:00  Solar Thermal       619.8  2023      8   31    23
#
# [96349 rows x 6 columns]

# %% [markdown]
# ### Process `pivot_table`
#
# - Use this methodology.

# %%
# Out:
# year                       2022                                         \
# month                        9            10           11           12
# technology
# Coal                 639985.519   389282.273   338313.851   725039.354
# Cogeneration         758832.665  1117045.451  1453732.367  1114179.283
# ...                         ...          ...          ...          ...
# Solar Photovoltaic  2636219.180  2056758.270  1535995.490  1176871.031
# Solar Thermal        443376.236   192219.608   113865.200    67765.475
#
# year                       2023                                         \
# month                        1            2            3            4
# technology
# Coal                 321210.350   431672.925   414233.325   254348.325
# Cogeneration        1222612.611  1718877.593  1771577.988  1590191.493
# ...                         ...          ...          ...          ...
# Solar Photovoltaic  1744956.450  2181165.122  2985426.080  3635891.249
# Solar Thermal        129341.585   189183.825   416953.986   645285.245
#
# year
# month                        5            6            7            8
# technology
# Coal                 247080.557   300360.567   287284.165   421115.277
# Cogeneration        1723153.516  1775275.345  1513263.491  1316018.962
# ...                         ...          ...          ...          ...
# Solar Photovoltaic  3803151.814  3855930.011  4491017.672  4403223.582
# Solar Thermal        518091.793   581982.910   800023.053   757878.191
#
# [11 rows x 12 columns]

# %% [markdown]
# ### Style DataFrame

# %%
# Out:
# <style type="text/css">
# #T_96d2e_row0_col0, #T_96d2e_row1_col9, #T_96d2e_row2_col4 {
#   background-color: #f9812e;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col1 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col2 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col3 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col5 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col6 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col7, #T_96d2e_row1_col0 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col8 {
#   background-color: #de5005;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col9 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_96d2e_row0_col10, #T_96d2e_row1_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_96d2e_row0_col11 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col1 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col2 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col3 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col4 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col5 {
#   background-color: #f26c16;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col6, #T_96d2e_row1_col10 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col7 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_96d2e_row1_col11 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_96d2e_row2_col0 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_96d2e_row2_col1, #T_96d2e_row5_col0, #T_96d2e_row10_col11 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_96d2e_row2_col2 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_96d2e_row2_col3 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_96d2e_row2_col5 {
#   background-color: #fdb87c;
#   color: #000000;
# }
# #T_96d2e_row2_col6 {
#   background-color: #fdc590;
#   color: #000000;
# }
# #T_96d2e_row2_col7 {
#   background-color: #fdd5ad;
#   color: #000000;
# }
# #T_96d2e_row2_col8 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_96d2e_row2_col9 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_96d2e_row2_col10 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_96d2e_row2_col11 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_96d2e_row3_col0 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col1 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col2 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col3 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col4 {
#   background-color: #fdc794;
#   color: #000000;
# }
# #T_96d2e_row3_col5 {
#   background-color: #fb8836;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col6 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_96d2e_row3_col7 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_96d2e_row3_col8 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_96d2e_row3_col9 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col10 {
#   background-color: #f4721e;
#   color: #f1f1f1;
# }
# #T_96d2e_row3_col11 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_96d2e_row4_col0 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_96d2e_row4_col1 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_96d2e_row4_col2 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_96d2e_row4_col3 {
#   background-color: #fee2c6;
#   color: #000000;
# }
# #T_96d2e_row4_col4 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_96d2e_row4_col5 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_96d2e_row4_col6 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_96d2e_row4_col7 {
#   background-color: #fd9141;
#   color: #000000;
# }
# #T_96d2e_row4_col8 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_96d2e_row4_col9 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_96d2e_row4_col10 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_96d2e_row4_col11 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_96d2e_row5_col1, #T_96d2e_row5_col3 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_96d2e_row5_col2 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_96d2e_row5_col4 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_96d2e_row5_col5, #T_96d2e_row5_col8 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_96d2e_row5_col6, #T_96d2e_row5_col9 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_96d2e_row5_col7 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_96d2e_row5_col10 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_96d2e_row5_col11 {
#   background-color: #fedebf;
#   color: #000000;
# }
# #T_96d2e_row6_col0, #T_96d2e_row7_col7, #T_96d2e_row7_col8 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_96d2e_row6_col1, #T_96d2e_row6_col11, #T_96d2e_row7_col2, #T_96d2e_row8_col0, #T_96d2e_row8_col3, #T_96d2e_row8_col8, #T_96d2e_row8_col9, #T_96d2e_row8_col10, #T_96d2e_row8_col11 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_96d2e_row6_col2, #T_96d2e_row6_col9, #T_96d2e_row6_col10, #T_96d2e_row7_col10, #T_96d2e_row8_col7 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_96d2e_row6_col3, #T_96d2e_row6_col8, #T_96d2e_row8_col1, #T_96d2e_row8_col2, #T_96d2e_row8_col5 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_96d2e_row6_col4, #T_96d2e_row6_col6, #T_96d2e_row6_col7, #T_96d2e_row7_col5, #T_96d2e_row7_col6, #T_96d2e_row7_col11, #T_96d2e_row10_col6 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_96d2e_row6_col5 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_96d2e_row7_col0 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_96d2e_row7_col1 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_96d2e_row7_col3 {
#   background-color: #feebd7;
#   color: #000000;
# }
# #T_96d2e_row7_col4, #T_96d2e_row7_col9, #T_96d2e_row8_col4, #T_96d2e_row8_col6 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_96d2e_row9_col0, #T_96d2e_row9_col2, #T_96d2e_row9_col4, #T_96d2e_row9_col5, #T_96d2e_row9_col6, #T_96d2e_row9_col9, #T_96d2e_row9_col11 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_96d2e_row9_col1, #T_96d2e_row9_col3, #T_96d2e_row9_col10, #T_96d2e_row10_col1, #T_96d2e_row10_col5 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_96d2e_row9_col7, #T_96d2e_row10_col4 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_96d2e_row9_col8, #T_96d2e_row10_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_96d2e_row10_col0 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_96d2e_row10_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_96d2e_row10_col7 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_96d2e_row10_col8 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_96d2e_row10_col9 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_96d2e_row10_col10 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# </style>
# <table id="T_96d2e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_96d2e_level0_col0" class="col_heading level0 col0" colspan="4">2022</th>
#       <th id="T_96d2e_level0_col4" class="col_heading level0 col4" colspan="8">2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >month</th>
#       <th id="T_96d2e_level1_col0" class="col_heading level1 col0" >9</th>
#       <th id="T_96d2e_level1_col1" class="col_heading level1 col1" >10</th>
#       <th id="T_96d2e_level1_col2" class="col_heading level1 col2" >11</th>
#       <th id="T_96d2e_level1_col3" class="col_heading level1 col3" >12</th>
#       <th id="T_96d2e_level1_col4" class="col_heading level1 col4" >1</th>
#       <th id="T_96d2e_level1_col5" class="col_heading level1 col5" >2</th>
#       <th id="T_96d2e_level1_col6" class="col_heading level1 col6" >3</th>
#       <th id="T_96d2e_level1_col7" class="col_heading level1 col7" >4</th>
#       <th id="T_96d2e_level1_col8" class="col_heading level1 col8" >5</th>
#       <th id="T_96d2e_level1_col9" class="col_heading level1 col9" >6</th>
#       <th id="T_96d2e_level1_col10" class="col_heading lev

# %%
# Out:
# <style type="text/css">
# #T_6e824_row0_col0 {
#   background-color: #f87f2c;
#   color: #f1f1f1;
# }
# #T_6e824_row0_col1 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_6e824_row0_col2, #T_6e824_row0_col3, #T_6e824_row0_col4, #T_6e824_row0_col5, #T_6e824_row0_col6, #T_6e824_row0_col7, #T_6e824_row0_col8, #T_6e824_row1_col10, #T_6e824_row1_col11, #T_6e824_row3_col0, #T_6e824_row3_col1, #T_6e824_row3_col9 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_6e824_row0_col9 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_6e824_row0_col10 {
#   background-color: #de4e05;
#   color: #f1f1f1;
# }
# #T_6e824_row0_col11 {
#   background-color: #b83c02;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col0 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col1 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col2 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col3 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col4 {
#   background-color: #e75b0b;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col5 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col6 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col7 {
#   background-color: #902e04;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col8 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_6e824_row1_col9 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_6e824_row2_col0, #T_6e824_row5_col1 {
#   background-color: #fee2c7;
#   color: #000000;
# }
# #T_6e824_row2_col1 {
#   background-color: #feebd7;
#   color: #000000;
# }
# #T_6e824_row2_col2 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_6e824_row2_col3, #T_6e824_row3_col8 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_6e824_row2_col4 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_6e824_row2_col5 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_6e824_row2_col6 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_6e824_row2_col7 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_6e824_row2_col8 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_6e824_row2_col9, #T_6e824_row4_col6 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_6e824_row2_col10 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_6e824_row2_col11, #T_6e824_row5_col3 {
#   background-color: #fedcb9;
#   color: #000000;
# }
# #T_6e824_row3_col2 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_6e824_row3_col3 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_6e824_row3_col4 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_6e824_row3_col5 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_6e824_row3_col6 {
#   background-color: #fdad69;
#   color: #000000;
# }
# #T_6e824_row3_col7 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_6e824_row3_col10 {
#   background-color: #ad3803;
#   color: #f1f1f1;
# }
# #T_6e824_row3_col11 {
#   background-color: #a93703;
#   color: #f1f1f1;
# }
# #T_6e824_row4_col0 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_6e824_row4_col1 {
#   background-color: #fdc590;
#   color: #000000;
# }
# #T_6e824_row4_col2 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_6e824_row4_col3 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_6e824_row4_col4 {
#   background-color: #fdd5ad;
#   color: #000000;
# }
# #T_6e824_row4_col5 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_6e824_row4_col7 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_6e824_row4_col8 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_6e824_row4_col9 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# #T_6e824_row4_col10, #T_6e824_row4_col11 {
#   background-color: #a63603;
#   color: #f1f1f1;
# }
# #T_6e824_row5_col0 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_6e824_row5_col2 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_6e824_row5_col4 {
#   background-color: #fee2c6;
#   color: #000000;
# }
# #T_6e824_row5_col5 {
#   background-color: #fdb77a;
#   color: #000000;
# }
# #T_6e824_row5_col6 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_6e824_row5_col7, #T_6e824_row5_col8 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_6e824_row5_col9 {
#   background-color: #fda45d;
#   color: #000000;
# }
# #T_6e824_row5_col10 {
#   background-color: #fdcb9b;
#   color: #000000;
# }
# #T_6e824_row5_col11 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_6e824_row6_col0 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_6e824_row6_col1, #T_6e824_row6_col2, #T_6e824_row6_col9, #T_6e824_row7_col4, #T_6e824_row7_col7, #T_6e824_row8_col0, #T_6e824_row8_col4 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_6e824_row6_col3, #T_6e824_row7_col5 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_6e824_row6_col4, #T_6e824_row8_col2, #T_6e824_row8_col5 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_6e824_row6_col5, #T_6e824_row9_col2 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_6e824_row6_col6, #T_6e824_row6_col11, #T_6e824_row7_col6, #T_6e824_row8_col9, #T_6e824_row8_col11, #T_6e824_row10_col0, #T_6e824_row10_col6 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_6e824_row6_col7, #T_6e824_row7_col0 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_6e824_row6_col8, #T_6e824_row7_col11, #T_6e824_row8_col3, #T_6e824_row8_col8 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_6e824_row6_col10 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_6e824_row7_col1, #T_6e824_row7_col8, #T_6e824_row7_col9, #T_6e824_row8_col1, #T_6e824_row8_col10 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_6e824_row7_col2, #T_6e824_row8_col7 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_6e824_row7_col3, #T_6e824_row10_col11 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# #T_6e824_row7_col10, #T_6e824_row8_col6, #T_6e824_row9_col3 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_6e824_row9_col0, #T_6e824_row9_col1, #T_6e824_row9_col5, #T_6e824_row9_col6, #T_6e824_row9_col7, #T_6e824_row9_col8, #T_6e824_row9_col9, #T_6e824_row9_col10, #T_6e824_row9_col11, #T_6e824_row10_col1, #T_6e824_row10_col2, #T_6e824_row10_col3, #T_6e824_row10_col4, #T_6e824_row10_col5 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_6e824_row9_col4 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_6e824_row10_col7 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_6e824_row10_col8 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_6e824_row10_col9 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_6e824_row10_col10 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# </style>
# <table id="T_6e824">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_6e824_level0_col0" class="col_heading level0 col0" colspan="4">2022</th>
#       <th id="T_6e824_level0_col4" class="col_heading level0 col4" colspan="8">2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >month</th>
#       <th id="T_6e824_level1_col0" class="col_heading level1 col0" >9</th>
#       <th id="T_6e824_level1_col1" class="col_heading level1 col1" >10</th>
#       <th id="T_6e824_level1_col2" class="col_heading level1 col2" >11</th>
#       <th id="T_6e824_level1_col3" class="col_heading level1 col3" >12</th>
#       <th id="T_6e824_level1_col4" class="col_heading level1 col4" >1</th>
#       <th id="T_6e824_level1_col5" class="col_heading level1 col5" >2</th>
#       <th id="T_6e824_level1_col6" class="col_heading level1 col6" >3</th>
#       <th id="T_6e824_level1_col7" class="col_heading level1 col7" >4</th>
#       <th id="T_6e824_level1_col8" class="col_heading level1 col8" >5</th>
#       <th id="T_6e824_level1_col9" class="col_heading level1 col9" >6</th>
#       <th id="T_6e824_level1_col10" class="col_heading level1 col10" >7</th>
#       <th id="T_6e824_level1_col11" class="col_heading level1 col11" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >technology</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >
