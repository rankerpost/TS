# %% [markdown]
# # Univariate Time Series Manipulation & Visualization

# %% [markdown]
# ## Overview

# %% [markdown]
# <style>
#     table.custom-table {
#         max-width: 1000px;
#         width: 100%;
#         margin: 0 auto; /* centers the table on the page */
#     }
#
#     table.custom-table td {
#         background-color: #fff;
#     }
#
#     table.custom-table th, table.custom-table td {
#         text-align: center;
#         vertical-align: middle;
#         padding: 5px;
#         width: 500px; /* distribute the total width equally among three columns */
#     }
#
#     table.custom-table img {
#         width: 100%;
#         display: block; /* removes any gap under the image */
#     }
# </style>
#
#
# <table class="custom-table">
#     <thead>
#         <tr>
#             <th>Output: Total Solar Energy Generation (Hour-Month) </th>
#             <th>Input: Hourly Solar Energy Generation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <img src="src/01_output.png">
#             </td>
#             <td>
#                 <img src="src/01_input.png">
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Data

# %%
#!

import pandas as pd

df = pd.read_csv('../../../data/energy_generation_hourly_year.csv', index_col=0, parse_dates=True)
df
# Out:
#                       Coal  Cogeneration  Combined Cycle (Gas)     Eolic  \
# time
# 2022-09-01 00:00:00  695.0        1155.1             14748.950  4387.050
# 2022-09-01 01:00:00  750.0        1162.1             14255.600  4008.900
# ...                    ...           ...                   ...       ...
# 2023-08-31 22:00:00  477.5        2153.4             10575.375  3057.950
# 2023-08-31 23:00:00  500.0        2127.7              9988.875  3028.675
#
#                      Hydraulic  Non-Renewable Residues  Nuclear  \
# time
# 2022-09-01 00:00:00    899.675                   273.7   6869.9
# 2022-09-01 01:00:00    850.200                   271.6   6881.9
# ...                        ...                     ...      ...
# 2023-08-31 22:00:00   3541.400                   239.4   6866.0
# 2023-08-31 23:00:00   3159.500                   240.8   6869.0
#
#                      Pumped Storage Hydropower  Renewables Other  \
# time
# 2022-09-01 00:00:00                     201.60             516.6
# 2022-09-01 01:00:00                     117.70             514.4
# ...                                        ...               ...
# 2023-08-31 22:00:00                     946.25             510.7
# 2023-08-31 23:00:00                     334.95             511.9
#
#                      Solar Photovoltaic  Solar Thermal
# time
# 2022-09-01 00:00:00                 1.0          287.7
# 2022-09-01 01:00:00                 1.0          247.7
# ...                                 ...            ...
# 2023-08-31 22:00:00                17.6          607.9
# 2023-08-31 23:00:00                17.4          619.8
#
# [8759 rows x 11 columns]

# %%
# Out:
# time
# 2022-09-01 00:00:00     1.0
# 2022-09-01 01:00:00     1.0
#                        ...
# 2023-08-31 22:00:00    17.6
# 2023-08-31 23:00:00    17.4
# Name: Solar Photovoltaic, Length: 8759, dtype: float64

# %%
# Out:
# time
# 2022-09-01 00:00:00     1.0
# 2022-09-01 01:00:00     1.0
#                        ...
# 2023-08-31 22:00:00    17.6
# 2023-08-31 23:00:00    17.4
# Name: Solar Photovoltaic, Length: 8759, dtype: float64

# %%
# Out:
# <AxesSubplot: xlabel='time'>

# %% [markdown]
# ## Resampling the Time
# - [Date offset `rule` list](https://pandas.pydata.org/docs/user_guide/timeseries.html#dateoffset-objects)
# - [Pandas plot `kind` list](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Daily

# %%
# Out:
# <AxesSubplot: xlabel='time'>

# %% [markdown]
# ### Monthly

# %%
# Out:
# <AxesSubplot: xlabel='time'>

# %%
# Out:
# <AxesSubplot: xlabel='time'>

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### Transform object to DataFrame
#
# > Only if you don't have a DataFrame yet.

# %%
# Out:
#                      Solar Photovoltaic
# time
# 2022-09-01 00:00:00                 1.0
# 2022-09-01 01:00:00                 1.0
# ...                                 ...
# 2023-08-31 22:00:00                17.6
# 2023-08-31 23:00:00                17.4
#
# [8759 rows x 1 columns]

# %% [markdown]
# ### Create columns with datetime information

# %%
# Out:
#                      Solar Photovoltaic  year  month  day  hour
# time
# 2022-09-01 00:00:00                 1.0  2022      9    1     0
# 2022-09-01 01:00:00                 1.0  2022      9    1     1
# ...                                 ...   ...    ...  ...   ...
# 2023-08-31 22:00:00                17.6  2023      8   31    22
# 2023-08-31 23:00:00                17.4  2023      8   31    23
#
# [8759 rows x 5 columns]

# %% [markdown]
# ### Process `pivot_table`
#
# - Use this methodology.

# %% [markdown]
# ### Style DataFrame

# %%
# Out:
# <style type="text/css">
# #T_08b0d_row0_col0, #T_08b0d_row0_col1, #T_08b0d_row0_col2, #T_08b0d_row0_col3, #T_08b0d_row0_col4, #T_08b0d_row0_col5, #T_08b0d_row0_col6, #T_08b0d_row0_col7, #T_08b0d_row0_col8, #T_08b0d_row0_col9, #T_08b0d_row0_col10, #T_08b0d_row0_col11, #T_08b0d_row1_col0, #T_08b0d_row1_col1, #T_08b0d_row1_col2, #T_08b0d_row1_col3, #T_08b0d_row1_col4, #T_08b0d_row1_col5, #T_08b0d_row1_col6, #T_08b0d_row1_col7, #T_08b0d_row1_col8, #T_08b0d_row1_col9, #T_08b0d_row1_col10, #T_08b0d_row1_col11, #T_08b0d_row2_col0, #T_08b0d_row2_col1, #T_08b0d_row2_col2, #T_08b0d_row2_col3, #T_08b0d_row2_col4, #T_08b0d_row2_col5, #T_08b0d_row2_col6, #T_08b0d_row2_col7, #T_08b0d_row2_col8, #T_08b0d_row2_col9, #T_08b0d_row2_col10, #T_08b0d_row2_col11, #T_08b0d_row3_col0, #T_08b0d_row3_col1, #T_08b0d_row3_col2, #T_08b0d_row3_col3, #T_08b0d_row3_col4, #T_08b0d_row3_col5, #T_08b0d_row3_col6, #T_08b0d_row3_col7, #T_08b0d_row3_col8, #T_08b0d_row3_col9, #T_08b0d_row3_col10, #T_08b0d_row3_col11, #T_08b0d_row4_col0, #T_08b0d_row4_col1, #T_08b0d_row4_col2, #T_08b0d_row4_col3, #T_08b0d_row4_col4, #T_08b0d_row4_col5, #T_08b0d_row4_col6, #T_08b0d_row4_col7, #T_08b0d_row4_col8, #T_08b0d_row4_col9, #T_08b0d_row4_col10, #T_08b0d_row4_col11, #T_08b0d_row5_col0, #T_08b0d_row5_col1, #T_08b0d_row5_col2, #T_08b0d_row5_col3, #T_08b0d_row5_col4, #T_08b0d_row5_col5, #T_08b0d_row5_col6, #T_08b0d_row5_col7, #T_08b0d_row5_col8, #T_08b0d_row5_col9, #T_08b0d_row5_col10, #T_08b0d_row5_col11, #T_08b0d_row6_col0, #T_08b0d_row6_col1, #T_08b0d_row6_col2, #T_08b0d_row6_col3, #T_08b0d_row6_col4, #T_08b0d_row6_col5, #T_08b0d_row6_col6, #T_08b0d_row6_col7, #T_08b0d_row6_col8, #T_08b0d_row6_col9, #T_08b0d_row6_col10, #T_08b0d_row6_col11, #T_08b0d_row7_col0, #T_08b0d_row7_col1, #T_08b0d_row7_col2, #T_08b0d_row7_col3, #T_08b0d_row7_col4, #T_08b0d_row7_col5, #T_08b0d_row18_col3, #T_08b0d_row19_col2, #T_08b0d_row19_col3, #T_08b0d_row19_col4, #T_08b0d_row19_col5, #T_08b0d_row20_col1, #T_08b0d_row20_col2, #T_08b0d_row20_col3, #T_08b0d_row20_col4, #T_08b0d_row20_col5, #T_08b0d_row21_col0, #T_08b0d_row21_col1, #T_08b0d_row21_col2, #T_08b0d_row21_col3, #T_08b0d_row21_col4, #T_08b0d_row21_col5, #T_08b0d_row21_col6, #T_08b0d_row21_col7, #T_08b0d_row22_col0, #T_08b0d_row22_col1, #T_08b0d_row22_col2, #T_08b0d_row22_col3, #T_08b0d_row22_col4, #T_08b0d_row22_col5, #T_08b0d_row22_col6, #T_08b0d_row22_col7, #T_08b0d_row22_col8, #T_08b0d_row22_col9, #T_08b0d_row22_col10, #T_08b0d_row22_col11, #T_08b0d_row23_col0, #T_08b0d_row23_col1, #T_08b0d_row23_col2, #T_08b0d_row23_col3, #T_08b0d_row23_col4, #T_08b0d_row23_col5, #T_08b0d_row23_col6, #T_08b0d_row23_col7, #T_08b0d_row23_col8, #T_08b0d_row23_col9, #T_08b0d_row23_col10, #T_08b0d_row23_col11 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_08b0d_row7_col6, #T_08b0d_row7_col11, #T_08b0d_row8_col3, #T_08b0d_row8_col4 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_08b0d_row7_col7, #T_08b0d_row20_col6, #T_08b0d_row21_col8 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_08b0d_row7_col8, #T_08b0d_row17_col3 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_08b0d_row7_col9, #T_08b0d_row8_col0, #T_08b0d_row17_col2 {
#   background-color: #feeddb;
#   color: #000000;
# }
# #T_08b0d_row7_col10, #T_08b0d_row18_col5, #T_08b0d_row20_col7 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_08b0d_row8_col1, #T_08b0d_row21_col9, #T_08b0d_row21_col10 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_08b0d_row8_col2, #T_08b0d_row19_col6 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_08b0d_row8_col5 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_08b0d_row8_col6, #T_08b0d_row9_col1 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_08b0d_row8_col7 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_08b0d_row8_col8, #T_08b0d_row17_col5 {
#   background-color: #fdc794;
#   color: #000000;
# }
# #T_08b0d_row8_col9 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_08b0d_row8_col10 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_08b0d_row8_col11 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_08b0d_row9_col0 {
#   background-color: #fdc590;
#   color: #000000;
# }
# #T_08b0d_row9_col2 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_08b0d_row9_col3, #T_08b0d_row20_col11 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_08b0d_row9_col4 {
#   background-color: #fedfc0;
#   color: #000000;
# }
# #T_08b0d_row9_col5 {
#   background-color: #fdc997;
#   color: #000000;
# }
# #T_08b0d_row9_col6 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_08b0d_row9_col7, #T_08b0d_row13_col2, #T_08b0d_row16_col1 {
#   background-color: #fd9040;
#   color: #000000;
# }
# #T_08b0d_row9_col8, #T_08b0d_row12_col1, #T_08b0d_row18_col7, #T_08b0d_row18_col8 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_08b0d_row9_col9 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_08b0d_row9_col10, #T_08b0d_row10_col6 {
#   background-color: #ec620f;
#   color: #f1f1f1;
# }
# #T_08b0d_row9_col11 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_08b0d_row10_col0, #T_08b0d_row10_col5 {
#   background-color: #fd8e3d;
#   color: #f1f1f1;
# }
# #T_08b0d_row10_col1, #T_08b0d_row14_col3 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_08b0d_row10_col2 {
#   background-color: #fda965;
#   color: #000000;
# }
# #T_08b0d_row10_col3 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_08b0d_row10_col4 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_08b0d_row10_col7, #T_08b0d_row10_col9 {
#   background-color: #e15407;
#   color: #f1f1f1;
# }
# #T_08b0d_row10_col8 {
#   background-color: #de5005;
#   color: #f1f1f1;
# }
# #T_08b0d_row10_col10, #T_08b0d_row10_col11, #T_08b0d_row12_col9 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col0 {
#   background-color: #f36f1a;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col1 {
#   background-color: #fc8937;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col2, #T_08b0d_row14_col2 {
#   background-color: #fd9649;
#   color: #000000;
# }
# #T_08b0d_row11_col3, #T_08b0d_row18_col0 {
#   background-color: #fdb271;
#   color: #000000;
# }
# #T_08b0d_row11_col4, #T_08b0d_row15_col4 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col5 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col6 {
#   background-color: #dc4c03;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col7 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col8 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col9 {
#   background-color: #cb4302;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col10 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_08b0d_row11_col11 {
#   background-color: #963003;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col0 {
#   background-color: #eb610f;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col2, #T_08b0d_row16_col5 {
#   background-color: #fd8f3e;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col3, #T_08b0d_row15_col2 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_08b0d_row12_col4, #T_08b0d_row14_col4 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col5, #T_08b0d_row14_col5 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col6 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col7, #T_08b0d_row14_col7 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col8, #T_08b0d_row14_col8, #T_08b0d_row17_col10 {
#   background-color: #b53b02;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col10 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# #T_08b0d_row12_col11, #T_08b0d_row15_col11 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col0 {
#   background-color: #e75c0c;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col1 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col3 {
#   background-color: #fda55f;
#   color: #000000;
# }
# #T_08b0d_row13_col4 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col5 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col6 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col7, #T_08b0d_row13_col8 {
#   background-color: #b03903;
#   color: #f1f1f1;
# }
# #T_08b0d_row13_col9
