# %% [markdown]
# # Modelling LSTM with Raw and Scaled Data

# %% [markdown]
# ## Load Dataset

# %%
# Out:
#                            Mercado SPOT
# datetime_utc
# 2020-01-01 00:00:00+00:00         38.60
# 2020-01-01 01:00:00+00:00         36.55
# ...                                 ...
# 2023-08-04 20:00:00+00:00         94.00
# 2023-08-04 21:00:00+00:00         91.70
#
# [31558 rows x 1 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Scale Data

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# ### Create Sequences

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Raw Data

# %%
# Out:
# 2023-08-06 19:12:11.817131: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
# Out:
# {'loss': [14710.7666015625,
#   11345.8408203125,
#   9207.1708984375,
#   7514.55908203125,
#   6146.80908203125,
#   5041.40087890625,
#   4136.90380859375,
#   3393.4150390625,
#   2786.914794921875,
#   2296.9755859375,
#   1899.478271484375,
#   1580.7880859375,
#   1328.34521484375,
#   1125.0120849609375,
#   964.3802490234375,
#   834.4616088867188,
#   728.7362670898438,
#   644.1802368164062,
#   574.3173828125,
#   545.2669677734375,
#   489.5091247558594,
#   442.4189147949219,
#   401.7495422363281,
#   366.479736328125,
#   335.8934631347656,
#   335.6994323730469,
#   303.8091735839844,
#   281.1081848144531],
#  'val_loss': [5988.09228515625,
#   4007.586181640625,
#   2637.19873046875,
#   1685.8575439453125,
#   1059.8594970703125,
#   667.2799072265625,
#   426.6972351074219,
#   284.15753173828125,
#   219.6842803955078,
#   169.5186004638672,
#   156.22860717773438,
#   156.06874084472656,
#   135.2489471435547,
#   136.2420654296875,
#   147.40223693847656,
# ...

# %% [markdown]
# ### Scaled Data

# %% [markdown]
# ### Compare History

# %%
# Out:
#       variable         value
# epoch
# 0          raw  14710.766602
# 1          raw  11345.840820
# ...        ...           ...
# 26      scaled           NaN
# 27      scaled           NaN
#
# [56 rows x 2 columns]

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Create DataFrame

# %% [markdown]
# #### Visualize Data

# %%
# Out:
#                            y_true  y_pred_raw  y_pred_scaled  \
# 2023-08-02 00:00:00+00:00   96.09   92.394020       0.131705
# 2023-08-02 01:00:00+00:00   96.09   93.599800       0.134128
# ...                           ...         ...            ...
# 2023-08-04 20:00:00+00:00   94.00   91.671135       0.133144
# 2023-08-04 21:00:00+00:00   91.70   87.295197       0.129027
#
#                            y_pred_scaled_inverse
# 2023-08-02 00:00:00+00:00              92.193771
# 2023-08-02 01:00:00+00:00              93.889854
# ...                                          ...
# 2023-08-04 20:00:00+00:00              93.200462
# 2023-08-04 21:00:00+00:00              90.318886
#
# [70 rows x 4 columns]

# %% [markdown]
# ### Evaluation

# %%
# Out:
# 10.989715585660388

# %%
# Out:
# 10.941397133468307
