# %% [markdown]
# # Data Sequence

# %% [markdown]
# ## Load Dataset

# %%
# Out:
#                            Mercado SPOT
# datetime_utc
# 2020-01-01 00:00:00+00:00         38.60
# 2020-01-01 01:00:00+00:00         36.55
# ...                                 ...
# 2023-08-04 20:00:00+00:00         94.00
# 2023-08-04 21:00:00+00:00         91.70
#
# [31558 rows x 1 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# ### Create Sequences

# %%
# Out:
#                            Mercado SPOT
# datetime_utc
# 2020-01-01 00:00:00+00:00         38.60
# 2020-01-01 01:00:00+00:00         36.55
# 2020-01-01 02:00:00+00:00         32.32

# %%
# Out:
# Mercado SPOT    30.85
# Name: 2020-01-01 03:00:00+00:00, dtype: float64

# %%
# Out:
# [                           Mercado SPOT
#  datetime_utc
#  2020-01-01 00:00:00+00:00         38.60
#  2020-01-01 01:00:00+00:00         36.55
#  ...                                 ...
#  2020-01-01 22:00:00+00:00         37.55
#  2020-01-01 23:00:00+00:00         35.40
#
#  [24 rows x 1 columns],
#                             Mercado SPOT
#  datetime_utc
#  2020-01-01 01:00:00+00:00         36.55
#  2020-01-01 02:00:00+00:00         32.32
#  ...                                 ...
#  2020-01-01 23:00:00+00:00         35.40
#  2020-01-02 00:00:00+00:00         31.98
#
#  [24 rows x 1 columns],
#                             Mercado SPOT
#  datetime_utc
#  2020-01-01 02:00:00+00:00         32.32
#  2020-01-01 03:00:00+00:00         30.85
#  ...                                 ...
#  2020-01-02 00:00:00+00:00         31.98
#  2020-01-02 01:00:00+00:00         30.50
#
#  [24 rows x 1 columns],
#                             Mercado SPOT
#  datetime_utc
# ...

# %% [markdown]
# ### Build LSTM Model
